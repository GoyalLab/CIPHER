# %% [markdown]
# # Figure 4 — CIPHER transfers across datasets and cell atlases
#
# Published panels **B** (cross-dataset ΔR² scatter across same-cell-type neuron datasets, correlation ≈ 0.73) and **C** (mean ΔR² transfer ladder: shuffled → mean-field → cross-dataset → true, same vs different cell type), reproduced with the `cipher` package on raw counts. Panels **D/E/F** are the CellxGene-atlas transfer produced by the shared atlas engine `notebooks/src/run_fig3_atlas.py` (E = T-cell/Marson, F = RPE). A is a schematic. Engine: `notebooks/src/run_fig4.py`.

# %%
import os, sys
import importlib as _il
try:
    _std_tqdm = _il.import_module('tqdm.std').tqdm
    for _m in ('tqdm','tqdm.auto','tqdm.notebook','tqdm.autonotebook'):
        try: _il.import_module(_m).tqdm = _std_tqdm
        except Exception: pass
except Exception: pass
sys.path.insert(0, os.path.dirname(os.getcwd()) if os.path.basename(os.getcwd()) in ("main","suppl") else os.getcwd())

from src.run_fig4 import *
from src.logutil import route_logs
DATA_DIR = os.environ["CIPHER_DATA_DIR"]
SUPPL = os.path.join(DATA_DIR, "suppl")
OUTDIR = os.environ.get("SUPPL_OUT", "resources/repro/fig4")
SUPPL_OUT = OUTDIR  # run_fig3_atlas (E/F) reads SUPPL_OUT
os.makedirs(OUTDIR, exist_ok=True)
route_logs("fig4_cross_dataset")
import src.run_fig4 as R
R.__dict__.update({k: v for k, v in globals().items() if k.isupper() or k in ("DATA_DIR","OUTDIR")})
# Out:
# [logs] verbose output -> ../../resources/repro/fig4/logs/fig4_cross_dataset.log

# %% [markdown]
# ## Panel B — cross-dataset ΔR² (same cell type)

# %%
R.panel_b()
# Out:
#        perturbation  pearson_true  pearson_cross  \
# 0      MAT2A_sgRNA2      0.991807       0.882018
# 1       UBA1_sgRNA1      0.986444       0.866969
# 2      RAB7A_sgRNA2      0.992857       0.860756
# 3      MAT2A_sgRNA1      0.923934       0.861106
# 4    MAP3K12_sgRNA2      0.601972       0.533761
# ..              ...           ...            ...
# 673            TFAM      0.688461       0.626657
# 674            CYCS      0.943048       0.868389
# 675             ACE      0.680649       0.843837
# 676           PDGFA      0.724160       0.596233
# 677            SNCB      0.798287       0.751060
#
#                                 pair
# 0    Tian19_neuron vs Tian21_CRISPRi
# 1    Tian19_neuron vs Tian21_CRISPRi
# 2    Tian19_neuron vs Tian21_CRISPRi
# 3    Tian19_neuron vs Tian21_CRISPRi
# 4    Tian19_neuron vs Tian21_CRISPRi
# ..                               ...
# 673  Tian21_CRISPRa vs Tian19_neuron
# 674  Tian21_CRISPRa vs Tian19_neuron
# ...

# %% [markdown]
# ## Panel C — covariance-transfer ladder (same vs different cell type)

# %%
R.panel_c()
# Out:
#               host          source   same      rand        mf     cross  \
# 0    Tian19_neuron     Tian19_iPSC   True  0.000124  0.014479  0.269540
# 1    Tian19_neuron  Tian21_CRISPRi   True  0.001713  0.133406  0.672715
# 2    Tian19_neuron  Tian21_CRISPRa   True  0.001722  0.232358  0.710755
# 3    Tian19_neuron   Replogle_rpe1  False  0.000098  0.050616  0.475180
# 4    Tian19_neuron          Norman  False  0.000101  0.113260  0.369598
# 5    Tian19_neuron        Frangieh  False  0.000079  0.021161  0.250203
# 6   Tian21_CRISPRi   Tian19_neuron   True  0.000550  0.088129  0.346110
# 7   Tian21_CRISPRi     Tian19_iPSC   True  0.000539  0.005952  0.074535
# 8   Tian21_CRISPRi  Tian21_CRISPRa   True  0.000285  0.139539  0.394740
# 9   Tian21_CRISPRi   Replogle_rpe1  False  0.001049  0.035266  0.273955
# 10  Tian21_CRISPRi          Norman  False  0.000507  0.037292  0.118699
# 11  Tian21_CRISPRi        Frangieh  False  0.000491  0.022491  0.128399
# ...

# %% [markdown]
# ## Panels E / F — CellxGene-atlas transfer (T-cell, RPE)
#
# Reuses `run_fig3_atlas`; run on the `cxg_ctmm` kernel. Panel D (brain/lung/intestine tissue atlas) uses the same engine with tissue-specific Census queries — see the atlas engine / `notebooks/src/download_cellxgene_atlas.py`.

# %%
# Panels E / F -- CellxGene-atlas transfer, reusing the shared atlas engine
# notebooks/src/run_fig3_atlas.py (E = T-cell/Marson pipeline, F = RPE pipeline). These are the
# same analyses as the suppl fig3_atlas notebook; they need the cxg_ctmm kernel (cellxgene_census)
# and reuse the cached covariance sources under $SUPPL_OUT.
import src.run_fig3_atlas as RA
import src.suppl_atlas as CA
_cfg = {k: v for k, v in globals().items() if k.isupper() or k in ("DATA_DIR","SUPPL","OUTDIR")}
RA.__dict__.update(_cfg); CA.__dict__.update(_cfg)

# %%
# E — T-cell atlas transfer (within dataset / within & cross condition / mean field)
RA.marson_cellxgene_robust_atlas_transfer()
# Out:
#                                          dataset                   label  \
# 0       Marson2025_D1_Rest_filtered__mean_ge_1p0      Marson2025_D1_Rest
# 1   Marson2025_D1_Stim48hr_filtered__mean_ge_1p0  Marson2025_D1_Stim48hr
# 2    Marson2025_D1_Stim8hr_filtered__mean_ge_1p0   Marson2025_D1_Stim8hr
# 3   Marson2025_D2_Stim48hr_filtered__mean_ge_1p0  Marson2025_D2_Stim48hr
# 4    Marson2025_D2_Stim8hr_filtered__mean_ge_1p0   Marson2025_D2_Stim8hr
# 5       Marson2025_D3_Rest_filtered__mean_ge_1p0      Marson2025_D3_Rest
# 6   Marson2025_D3_Stim48hr_filtered__mean_ge_1p0  Marson2025_D3_Stim48hr
# 7    Marson2025_D3_Stim8hr_filtered__mean_ge_1p0   Marson2025_D3_Stim8hr
# 8       Marson2025_D4_Rest_filtered__mean_ge_1p0      Marson2025_D4_Rest
# 9   Marson2025_D4_Stim48hr_filtered__mean_ge_1p0  Marson2025_D4_Stim48hr
# 10   Marson2025_D4_Stim8hr_filtered__mean_ge_1p0   Marson2025_D4_Stim8hr
#
#    condition                                        folder  n_genes  \
# ...

# %%
# F — RPE atlas transfer (within dataset / cross dataset / cross-condition mean field)
RA.rpe_first3_plus_far_from_rpe_atlas_streamed()
# Out:
#                                    dataset          label  \
# 0                ReplogleWeissman2022_rpe1  Replogle RPE1
# 1  kaden25_rpe1_ctrl_10k_min100_greedy_4gb     Kaden RPE1
#
#                                                 path      pert_key  n_genes  \
# 0    $CIPHER_DATA_DIR/ReplogleWeissman2022_rpe1.h5ad  perturbation     8749
# 1  $CIPHER_DATA_DIR/kaden25_rpe1_ctrl_10k_min100_...  perturbation    12661
#
#    n_perts  n_unique_targets  n_control_total  n_control_sigma
# 0      659               659            11485            10000
# 1     1044              1044            10000            10000
#                                       source_dataset  \
# 0  CELLxGENE_RPE_5ed90bc0-12f3-4354-b314-0ce0dbb9...
# 1                CELLxGENE_POOLED_FAR_FROM_RPE_ATLAS
#
#                                         source_label  \
# 0  RPE atlas1: retinal pigment epithelial cell | eye
# 1                Pooled CELLxGENE far-from-RPE atlas
#
# ...
